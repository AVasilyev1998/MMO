# %% [markdown]
# #  Лабораторная работа № 1
#
# # Васильев А.Р. ИУ5-24М
#
# ## Создание "истории о данных" (Data Storytelling)
#
# ## Задание:
# * Выбрать набор данных (датасет). Вы можете найти список свободно распространяемых датасетов здесь. Для лабораторных работ не рекомендуется выбирать датасеты очень большого размера.
#
# * Создать "историю о данных" в виде юпитер-ноутбука, с учетом следующих требований:
#     1. История должна содержать не менее 5 шагов (где 5 - рекомендуемое количество шагов). Каждый шаг содержит график и его текстовую интерпретацию.
#     2. На каждом шаге наряду с удачным итоговым графиком рекомендуется в юпитер-ноутбуке оставлять результаты предварительных "неудачных" графиков.
#     3. Не рекомендуется повторять виды графиков, желательно создать 5 графиков различных видов.
#     4. Выбор графиков должен быть обоснован использованием методологии data-to-viz. Рекомендуется учитывать типичные ошибки построения выбранного вида графика по методологии data-to-viz. Если методология Вами отвергается, то просьба обосновать Ваше решение по выбору графика.
#     5. История должна содержать итоговые выводы. В реальных "историях о данных" именно эти выводы представляют собой основную ценность для предприятия.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import plotly.express as px
from datetime import datetime

# %% [markdown]
# # Был выбран датасет обращений в 911
#
# ## Описание датасета
#
# Датасет вызовов 911
#
# ## Колонки
#
# * lat - latitude - широта
# * lng - longitude - долгота
# * desc - description - описание
# * zip - zip - почтовый индекс
# * title - title - причина вызова
# * timestamp - timestamp - дата/время
# * twp - township - населенный пункт
# * addr - address - адрес
# * e - some index - всегда 1

# %%
df = pd.read_csv('data/911.csv')

# %%
df.head()
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4  40.251492 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
#
#        zip                    title            timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY  2015-12-10 17:10:52        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY  2015-12-10 17:29:21  HATFIELD TOWNSHIP
# 2  19401.0      Fire: GAS-ODOR/LEAK  2015-12-10 14:39:21         NORRISTOWN
# 3  19401.0   EMS: CARDIAC EMERGENCY  2015-12-10 16:47:36         NORRISTOWN
# 4      NaN           EMS: DIZZINESS  2015-12-10 16:56:52   LOWER POTTSGROVE
#
#                          addr  e
# 0      REINDEER CT & DEAD END  1
# 1  BRIAR PATH & WHITEMARSH LN  1
# 2                    HAWS AVE  1
# 3          AIRY ST & SWEDE ST  1
# 4    CHERRYWOOD CT & DEAD END  1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 663522 entries, 0 to 663521
# Data columns (total 9 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   lat        663522 non-null  float64
#  1   lng        663522 non-null  float64
#  2   desc       663522 non-null  object
#  3   zip        583323 non-null  float64
#  4   title      663522 non-null  object
#  5   timeStamp  663522 non-null  object
#  6   twp        663229 non-null  object
#  7   addr       663522 non-null  object
#  8   e          663522 non-null  int64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 45.6+ MB

# %%
df.describe()
# Out:
#                  lat            lng            zip         e
# count  663522.000000  663522.000000  583323.000000  663522.0
# mean       40.158162     -75.300105   19236.055791       1.0
# std         0.220641       1.672884     298.222637       0.0
# min         0.000000    -119.698206    1104.000000       1.0
# 25%        40.100344     -75.392735   19038.000000       1.0
# 50%        40.143927     -75.305143   19401.000000       1.0
# 75%        40.229008     -75.211865   19446.000000       1.0
# max        51.335390      87.854975   77316.000000       1.0

# %% [markdown]
# # Шаг 1. Рассмотрим уникальные типы случаев вызова

# %%
{i.split(':')[0] for i in df.title}
# Out:
# {'EMS', 'Fire', 'Traffic'}

# %%
df['type_of_emergency'] = df.title.apply(lambda x: x.split(':')[0])

# %% [markdown]
# ## Barplot

# %%
plt.figure(figsize=(7,5))
df['type_of_emergency'].value_counts().plot(kind='bar', cmap='winter')
plt.title('Распределение типов вызовов',fontsize=25)
plt.xlabel('Тип вызова')
plt.ylabel('Количество вызовов')
plt.show()

# %% [markdown]
# ## Леденец на палочке (lollipop plot)

# %%
BIGGER_SIZE = 14
AXES_SIZE = 20

plt.rc('axes', titlesize=AXES_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=AXES_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=BIGGER_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=BIGGER_SIZE)    # fontsize of the tick labels

# %%
emergency_types_dict = dict(df.type_of_emergency.value_counts())

plt.figure(figsize=(7,5))
plt.stem(emergency_types_dict.keys(), emergency_types_dict.values(),
         linefmt='-', use_line_collection=True)
plt.title('Распределение типов вызовов',fontsize=25)
plt.xlabel('Тип вызова')
plt.ylabel('Количество вызовов')
plt.show()

# %% [markdown]
# ## Пончик

# %%
types = list(emergency_types_dict.keys())
# print(types)
sizes = [emergency_types_dict[types[i]]/sum(list(emergency_types_dict.values())) for i in range(len(types))]
# print(sizes)

plt.figure(figsize=(8,6))
my_circle=plt.Circle( (-0.08,0.02), 0.8, color='white')
plt.pie(sizes, labels=types, colors=['indigo', 'goldenrod', 'red'], )
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.title('Распределение типов вызовов',fontsize=25)
plt.show()

# %% [markdown]
# ## Подытог: наиболее частым является вызов в связи с увечьями, следующими по популярности являются вызовы в связи с проблемами на дороге, далее вызовы связанные с пожарами.

# %% [markdown]
# # Шаг 2. Рассмотрим случаи вызова (Event_type)

# %%
df['event_type'] = df.title.apply(lambda x: x.split(':')[1].strip(' -;:'))
print(df.event_type.value_counts())

event_type_dict = dict(df.event_type.value_counts())
# Out:
# VEHICLE ACCIDENT         184749
# DISABLED VEHICLE          47917
# FIRE ALARM                38452
# FALL VICTIM               34683
# RESPIRATORY EMERGENCY     34250
#                           ...
# SUICIDE ATTEMPT               2
# ANIMAL COMPLAINT              1
# FOOT PATROL                   1
# PRISONER IN CUSTODY           1
# HIT + RUN                     1
# Name: event_type, Length: 88, dtype: int64

# %%
# неудачная попытка

items = [(k.lower().strip('-, ').capitalize(), v) for k,v in event_type_dict.items() if v > 1 ]



sorted(items, key=lambda x: x[1], reverse=True)



values = [i[1] for i in items ]
labels = [i[0] for i in items]

print(labels)

plt.figure(figsize=(16,25))
plt.hlines(y=np.arange(1, 92), xmin=0, xmax=values, color="indigo", zorder=0, linewidths=4)
plt.plot(values, np.arange(1,92), "o", markersize=8)
plt.yticks(np.arange(1,92), labels)
plt.show()
# Out:
# ['Vehicle accident', 'Disabled vehicle', 'Fire alarm', 'Fall victim', 'Respiratory emergency', 'Cardiac emergency', 'Road obstruction', 'Subject in pain', 'Head injury', 'General weakness', 'Seizures', 'Syncopal episode', 'Unknown medical emergency', 'Medical alert alarm', 'Altered mental status', 'Fire investigation', 'Abdominal pains', 'Unconscious subject', 'Overdose', 'Cva/stroke', 'Hemorrhaging', 'Nausea/vomiting', 'Gas-odor/leak', 'Hazardous road conditions', 'Vehicle fire', 'Cardiac arrest', 'Building fire', 'Diabetic emergency', 'Dizziness', 'Electrical fire outside', 'Back pains/injury', 'Carbon monoxide detector', 'Fire special service', 'Assault victim', 'Fracture', 'Fever', 'Allergic reaction', 'Lacerations', 'Unresponsive subject', 'Woods/field fire', 'Unknown type fire', 'Fire police needed', 'Dehydration', 'Ems special service', 'Appliance fire', 'Choking', 'Trash/dumpster fire', 'Maternity', 'Elevator emergency', 'Rescue - elevator', 'S/b at helicopter landing', 'Rescue - general', 'Vehicle leaking fuel', 'Animal bite', 'Rescue - water', 'Burn victim', 'Debris/fluids on highway', 'Heat exhaustion', 'Eye injury', 'Shooting', 'Poisoning', 'Stabbing', 'Pump detail', 'Transferred call', 'Hazardous materials incident', 'Amputation', 'Rescue - technical', 'Industrial accident', 'Electrocution', 'Drowning', 'Train crash', 'Standby for another co', 'Plane crash', 'Bomb device found', 'Warrant service', 'Suspicious', 'Public service', 'Police information', 'Active shooter', 'Barricaded subject', 'Armed subject', 'Suicide threat', 'Bomb threat', 'Suicide attempt']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-90-65755c67625c> in <module>
#      15
#      16 plt.figure(figsize=(16,25))
# ---> 17 plt.hlines(y=np.arange(1, 92), xmin=0, xmax=values, color="indigo", zorder=0, linewidths=4)
#      18 plt.plot(values, np.arange(1,92), "o", markersize=8)
#      19 plt.yticks(np.arange(1,92), labels)
#
# ~/git/MMO/env/lib/python3.8/site-packages/matplotlib/pyplot.py in hlines(y, xmin, xmax, colors, linestyles, label, data, **kwargs)
#    2709         y, xmin, xmax, colors=None, linestyles='solid', label='', *,
#    2710         data=None, **kwargs):
# -> 2711     return gca().hlines(
#    2712         y, xmin, xmax, colors=colors, linestyles=linestyles,
#    2713         label=label, **({"data": data} if data is not None else {}),
#
# ~/git/MMO/env/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/git/MMO/env/lib/python3.8/site-packages/matplotlib/axes/_axes.py in hlines(self, y, xmin, xmax, colors, linestyles, label, **kwargs)
#    1174         masked_verts[:, 0, 0] = xmin
#    1175         masked_verts[:, 0, 1] = y
# -> 1176         masked_verts[:, 1, 0] = xmax
#    1177         masked_verts[:, 1, 1] = y
#    1178
#
# ~/git/MMO/env/lib/python3.8/site-packages/numpy/ma/core.py in __setitem__(self, indx, value)
#    3372         if _mask is nomask:
#    3373             # Set the data, then the mask
# -> 3374             _data[indx] = dval
#    3375             if mval is not nomask:
#    3376                 _mask = self._mask = make_mask_none(self.shape, _dtype)
#
# ValueError: could not broadcast input array from shape (84,) into shape (91,)

# %%
fig = plt.figure(figsize=(16,25))
ax1 = fig.add_subplot(111)
ax1.xaxis.set_label_position('top') 
ax1.xaxis.set_ticks_position('top')

INDIGO_RGBA_COLOR = (0.365, 0, 0.634, 1)



event_types_df = pd.DataFrame({'labels':labels, 'values':values})
event_types_df = event_types_df.nlargest(30, 'values').sort_values(by='values')

plt.hlines(y=np.arange(1,31), xmin=0, xmax=event_types_df['values'], color='indigo', linewidth=5)
plt.plot(event_types_df['values'], np.arange(1,31), "o", markersize=11,
         markerfacecolor=INDIGO_RGBA_COLOR, markeredgecolor=INDIGO_RGBA_COLOR)
plt.yticks(np.arange(1,31), event_types_df['labels'])
plt.xlabel('Количество вызовов')
plt.ylabel('Описание случая')
plt.minorticks_on()
plt.grid(axis='x')
plt.title('30 наиболее частых вызовов', fontsize=25)
plt.show()

# %% [markdown]
# ## Подытог: наиболее часто обращаются в связи с проблемами с автомобилем (аварии и поломки)

# %% [markdown]
# # Шаг 3. Рассмотрим количество случаев по дням

# %%
df.timeStamp
# Out:
# 0         2015-12-10 17:10:52
# 1         2015-12-10 17:29:21
# 2         2015-12-10 14:39:21
# 3         2015-12-10 16:47:36
# 4         2015-12-10 16:56:52
#                  ...
# 663517    2020-07-29 15:46:51
# 663518    2020-07-29 15:52:19
# 663519    2020-07-29 15:52:52
# 663520    2020-07-29 15:54:08
# 663521    2020-07-29 15:52:46
# Name: timeStamp, Length: 663522, dtype: object

# %%
df['date'] = df.timeStamp.apply(lambda x: x.split(' ')[0].strip())

data = [(label, value) for label,value in dict(df.date.value_counts()).items()]
sorted(data, key=lambda x: x[0])

label = [i[0] for i in data]
value = [np.log(i[1]) for i in data]

days_df = pd.DataFrame({'День':label, 'Кол-во вызовов':value})

# %%
fig = px.area(days_df, x='День', y='Кол-во вызовов', width=1000, height=500,
              title='Количество вызовов по дням (логарифм)')
fig.show()
# Out:
# <div>                            <div id="34f9e82e-01a6-4ec7-8794-6904c40a5d85" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("34f9e82e-01a6-4ec7-8794-6904c40a5d85")) {                    Plotly.newPlot(                        "34f9e82e-01a6-4ec7-8794-6904c40a5d85",                        [{"hovertemplate": "\u0414\u0435\u043d\u044c=%{x}<br>\u041a\u043e\u043b-\u0432\u043e \u0432\u044b\u0437\u043e\u0432\u043e\u0432=%{y}<extra></extra>", "legendgroup": "", "line": {"color": "#636efa"}, "mode": "lines", "name": "", "orientation": "v", "showlegend": false, "stackgroup": "1", "type": "scatter", "x": ["2018-03-02", "2018-11-15", "2020-06-03", "2018-03-07", "2018-03-03", "2016-01-23", "2019-11-01", "2019-07-11", "2020-01-18", "2019-02-25", "2018-08-13", "2016-02-24", "2017-12-15", "2016-01-24", "2017-06-21", "2018-11-03", "2019-05-29", "2018-05-15", "2020-06-04", "2018-01-05", "2018-01-12", "2019-10-31", "2018-01-04", "2019-06-20", "2016-04-03", "2016-01-12", "2019-08-07", "2017-01-23", "2016-07-25", "2018-06-28", "2018-12-21", "2016-01-25", "2016-12-17", "2016-11-29", "2016-02-16", "2018-01-03", "2019-03-04", "2020-07-06", "2020-07-10", "2019-10-17", "2019-04-26", "2018-11-16", "2017-12-09", "2017-10-09", "2019-02-13", "2016-02-15", "2019-02-12", "2018-11-02", "2018-07-03", "2017-10-24", "2017-02-13", "2018-09-26", "2019-01-22", "2018-04-16", "2015-12-23", "2019-06-29", "2019-12-20", "2018-02-05", "2017-01-11", "2017-12-13", "2019-07-17", "2019-02-01", "2017-02-09", "2017-12-30", "2018-09-12", "2019-12-09", "2019-03-01", "2016-09-29", "2016-01-26", "2017-03-14", "2020-02-07", "2019-01-24", "2018-05-17", "2019-10-16", "2018-03-08", "2017-06-19", "2016-10-28", "2016-10-21", "2019-10-03", "2017-03-15", "2016-09-30", "2018-11-06", "2019-10-22", "2018-01-02", "2019-06-28", "2019-05-13", "2020-03-06", "2020-06-05", "2017-07-24", "2018-01-09", "2019-11-26", "2017-12-19", "2018-12-28", "2019-05-20", "2016-12-16", "2017-09-05", "2019-03-15", "2017-03-02", "2018-10-15", "2018-11-26", "2018-06-11", "2019-07-19", "2019-07-22", "2018-03-05", "2018-03-21", "2018-09-19", "2017-06-30", "2019-03-03", "2019-02-20", "2018-09-07", "2019-06-10", "2018-07-17", "2018-10-31", "2017-12-01", "2018-01-10", "2018-01-06", "2018-04-04", "2018-09-28", "2016-07-13", "2018-01-08", "2019-10-24", "2016-11-30", "2016-09-19", "2018-10-11", "2019-03-02", "2018-06-14", "2019-02-04", "2018-11-23", "2017-04-28", "2017-12-14", "2018-09-04", "2016-10-07", "2017-05-17", "2016-01-22", "2019-07-16", "2018-10-10", "2018-08-11", "2019-10-23", "2019-01-29", "2019-12-13", "2019-12-17", "2019-08-01", "2020-03-09", "2018-09-25", "2018-07-02", "2017-05-25", "2017-10-30", "2018-09-10", "2019-05-31", "2017-06-24", "2018-02-17", "2018-07-22", "2017-11-07", "2019-04-03", "2019-05-17", "2016-02-02", "2019-12-18", "2017-06-20", "2017-05-18", "2017-12-05", "2017-06-22", "2020-02-13", "2018-12-10", "2016-06-08", "2017-08-23", "2019-12-10", "2018-12-20", "2016-11-11", "2018-11-08", "2018-12-18", "2018-10-27", "2019-01-21", "2018-10-12", "2017-11-16", "2016-11-19", "2019-12-23", "2016-09-09", "2020-01-25", "2016-11-18", "2016-05-13", "2019-01-25", "2019-10-04", "2017-03-17", "2019-10-02", "2019-02-02", "2019-08-30", "2018-05-02", "2018-12-14", "2016-12-06", "2018-11-24", "2019-05-30", "2019-09-03", "2018-11-09", "2017-11-17", "2017-05-13", "2020-03-03", "2018-11-05", "2019-10-21", "2017-07-21", "2016-10-22", "2017-05-02", "2016-10-19", "2018-03-06", "2019-12-04", "2019-09-12", "2016-05-26", "2019-02-05", "2018-09-18", "2019-04-15", "2020-01-16", "2019-10-30", "2017-02-24", "2018-09-05", "2018-06-01", "2018-06-18", "2019-05-24", "2018-12-11", "2016-04-01", "2019-03-20", "2016-11-22", "2016-10-17", "2019-10-29", "2018-02-07", "2019-09-20", "2017-05-19", "2019 ...

# %% [markdown]
# ## Подытог: не смотря на несколько пиков, в среднем количество вызовов за все время очень похожее

# %% [markdown]
# # Шаг 4. Рассмотрим среднее количество вызовов в день по годам

# %%
df['year'] = df['date'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d').year)
df['day'] = df['date'].apply(lambda x: str(datetime.strptime(x,'%Y-%m-%d').day) +
                             '/' + str(datetime.strptime(x,'%Y-%m-%d').month))

# %%
mean_val_per_day_dict = dict(df.groupby(df.year).day.agg(lambda x: x.size/np.unique(x).size))
mean_day_data = [(k,v) for k,v in mean_val_per_day_dict.items()]

year = [i[0] for i in mean_day_data]
vals = [i[1] for i in mean_day_data]

df_tmp = pd.DataFrame({'Год':year, 'Среднее кол-во вызовов в день':vals})

# %%
fig = px.line(df_tmp,x='Год', y='Среднее кол-во вызовов в день', title='Среднее кол-во вызовов в день по годам')
fig.show()
# Out:
# <div>                            <div id="d6c0b8c3-faa4-45c3-af78-a2aedd1f5041" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d6c0b8c3-faa4-45c3-af78-a2aedd1f5041")) {                    Plotly.newPlot(                        "d6c0b8c3-faa4-45c3-af78-a2aedd1f5041",                        [{"hovertemplate": "\u0413\u043e\u0434=%{x}<br>\u0421\u0440\u0435\u0434\u043d\u0435\u0435 \u043a\u043e\u043b-\u0432\u043e \u0432\u044b\u0437\u043e\u0432\u043e\u0432 \u0432 \u0434\u0435\u043d\u044c=%{y}<extra></extra>", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "orientation": "v", "showlegend": false, "type": "scatter", "x": [2015, 2016, 2017, 2018, 2019, 2020], "xaxis": "x", "y": [359.8181818181818, 388.9617486338798, 384.5013698630137, 415.14246575342463, 408.54246575342466, 342.45497630331755], "yaxis": "y"}],                        {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogra ...

# %% [markdown]
# ## Подытог: среднее количество вызовов 911 в день росло скачкообразно, с падением в 2017 году, вплоть до 2018 года, далее убывало до конца наблюдения - до 2020 года

# %% [markdown]
# # Шаг 5. Рассмотрим процентный прирост по количеству вызовов

# %%
df_tmp
# Out:
#     Год  Среднее кол-во вызовов в день
# 0  2015                     359.818182
# 1  2016                     388.961749
# 2  2017                     384.501370
# 3  2018                     415.142466
# 4  2019                     408.542466
# 5  2020                     342.454976

# %%
df_tmp['last_day'] = df_tmp['Среднее кол-во вызовов в день'].shift(1)


def add_percent(this, last):
    one_percent = this / 100
    print(one_percent)
    return (this-last) / one_percent


df_tmp['add_percent'] = df_tmp.apply(lambda x:add_percent(x['Среднее кол-во вызовов в день'], x.last_day), axis=1)

df_tmp['add_percent'][0] = 0
# Out:
# 3.598181818181818
# 3.889617486338798
# 3.8450136986301366
# 4.151424657534246
# 4.085424657534246
# 3.4245497630331756
# <ipython-input-104-fcf3b531a523>:12: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
fig = px.bar(df_tmp, x='Год',
              y='add_percent', title='Процентное изменение количества вызовов относительно прошлого года')
fig.show()
# Out:
# <div>                            <div id="2ea895bf-320c-435d-a227-d6f07eaf1db7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2ea895bf-320c-435d-a227-d6f07eaf1db7")) {                    Plotly.newPlot(                        "2ea895bf-320c-435d-a227-d6f07eaf1db7",                        [{"alignmentgroup": "True", "hovertemplate": "\u0413\u043e\u0434=%{x}<br>add_percent=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": [2015, 2016, 2017, 2018, 2019, 2020], "xaxis": "x", "y": [0.0, 7.492656261973487, -1.1600423614759032, 7.380862816527746, -1.615499134913282, -19.298154216796203], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], " ...

# %%
fig = px.line(df_tmp, x='Год',
              y='add_percent', title='Процентное изменение количества вызовов относительно прошлого года')
fig.show()
# Out:
# <div>                            <div id="6b194097-48d2-4973-ad16-3ed2038facbd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6b194097-48d2-4973-ad16-3ed2038facbd")) {                    Plotly.newPlot(                        "6b194097-48d2-4973-ad16-3ed2038facbd",                        [{"hovertemplate": "\u0413\u043e\u0434=%{x}<br>add_percent=%{y}<extra></extra>", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "orientation": "v", "showlegend": false, "type": "scatter", "x": [2015, 2016, 2017, 2018, 2019, 2020], "xaxis": "x", "y": [0.0, 7.492656261973487, -1.1600423614759032, 7.380862816527746, -1.615499134913282, -19.298154216796203], "yaxis": "y"}],                        {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, " ...

# %% [markdown]
# ## Подытог: аналогично предыдущему шагу рассмотрели все в процентах относительно предыдущего года. Вывод тот же: с 2015 по 2016 рост более 5%, 2016 - 2017 падение ~ 1-2 %,  2017-2018 - рост ~ 8%, 2018 - 2019 - подение около 2%, к 2020 му году значительное падение - около 20%

# %% [markdown]
# # Шаг 6. Рассмотрим количество вызовов по годам

# %%
df['year'] = df['date'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d').year)

labels = []
values = []
for k,v in df['year'].value_counts().items():
    labels.append(k)
    values.append(v)

# %%
year_df = pd.DataFrame({'Год':labels, 'Кол-во вызовов':values}).sort_values(by='Год',
                                                                            ascending=True)

# %%
fig = px.line(year_df, x='Год', y='Кол-во вызовов', title='Распределение вызовов по годам')
fig.show()
# Out:
# <div>                            <div id="37218d3d-7836-4128-8d8f-2af468f6c91a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("37218d3d-7836-4128-8d8f-2af468f6c91a")) {                    Plotly.newPlot(                        "37218d3d-7836-4128-8d8f-2af468f6c91a",                        [{"hovertemplate": "\u0413\u043e\u0434=%{x}<br>\u041a\u043e\u043b-\u0432\u043e \u0432\u044b\u0437\u043e\u0432\u043e\u0432=%{y}<extra></extra>", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "orientation": "v", "showlegend": false, "type": "scatter", "x": [2015, 2016, 2017, 2018, 2019, 2020], "xaxis": "x", "y": [7916, 142360, 140343, 151527, 149118, 72258], "yaxis": "y"}],                        {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0 ...

# %% [markdown]
# ## Подытог: по общему количеству вызовов видно что к 2020 году их количество значительно уменьшилось

# %% [markdown]
# # Шаг 7. Рассмотрим частоту вызова относительно дня недели

# %%
from datetime import datetime

# getting week day from date
df['week_day'] = df.date.apply(lambda x: datetime.strptime(x, '%Y-%m-%d').weekday())

# %%
day_dict = {0:'Вс', 1:'Пн', 2:'Вт', 3:'Ср', 4:'Чт', 5:'Пт', 6:'Сб'}

week_day_data = [(day_dict[labels], values) for labels, values in dict(df.week_day.value_counts()).items()]
sorted(week_day_data, key=lambda x: x[1])
week_day_data

days = [i[0] for i in week_day_data]
count = [i[1] for i in week_day_data]

week_day_df = pd.DataFrame({'День недели':days, 'Кол-во вызовов':count}).sort_values(by='Кол-во вызовов')

# %%
fig = px.bar(week_day_df , x="День недели", y='Кол-во вызовов', title="Количество вызовов по дням недели")
fig.show()
# Out:
# <div>                            <div id="e123f508-e355-4a07-bbed-42a990b7149f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e123f508-e355-4a07-bbed-42a990b7149f")) {                    Plotly.newPlot(                        "e123f508-e355-4a07-bbed-42a990b7149f",                        [{"alignmentgroup": "True", "hovertemplate": "\u0414\u0435\u043d\u044c \u043d\u0435\u0434\u0435\u043b\u0438=%{x}<br>\u041a\u043e\u043b-\u0432\u043e \u0432\u044b\u0437\u043e\u0432\u043e\u0432=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["\u0421\u0431", "\u041f\u0442", "\u0412\u0441", "\u041f\u043d", "\u0421\u0440", "\u0412\u0442", "\u0427\u0442"], "xaxis": "x", "y": [78859, 89452, 96745, 97684, 98683, 99157, 102942], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1. ...

# %% [markdown]
# ## Подытог: можно сказать, что количество вызовов в будние дни превышает количество вызовов в пт и выходные

# %% [markdown]
# # Шаг 8. Рассмотрим частоту вызовов относительно времени суток

# %%
import time 

df['time'] = df.timeStamp.apply(lambda x: datetime.strptime(x.split(' ')[1].strip(), '%H:%M:%S'))

df['time_categorized'] = df.time.apply(lambda x: 0 if x.hour >= 0 and x.hour < 6
                                       else 1 if x.hour >= 6 and x.hour < 12
                                       else 2 if x.hour >= 12 and x.hour < 18
                                       else 3 if x.hour >= 18 and x.hour <= 23 else -1)

# %%
# df.time_categorized.value_counts().plot(kind='bar')

time_interval_dict = {0:'night', 1:'morning', 2:'day', 3:'evening'}

time_data = sorted([(time_interval_dict[k],v) for k,v in df.time_categorized.value_counts().items()],
                   key=lambda x: x[1])

labels = [i[0] for i in time_data]
values = [i[1] for i in time_data]

time_df = pd.DataFrame({'День недели':labels, 'Кол-во вызовов':values})

fig = px.bar(time_df, x='День недели', y='Кол-во вызовов',
             width=900, height=500, title='Распределение вызовов по дням недели')
fig.show()
# Out:
# <div>                            <div id="9e92b7ea-f5c9-421b-82b0-8123caa96fc0" class="plotly-graph-div" style="height:500px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9e92b7ea-f5c9-421b-82b0-8123caa96fc0")) {                    Plotly.newPlot(                        "9e92b7ea-f5c9-421b-82b0-8123caa96fc0",                        [{"alignmentgroup": "True", "hovertemplate": "\u0414\u0435\u043d\u044c \u043d\u0435\u0434\u0435\u043b\u0438=%{x}<br>\u041a\u043e\u043b-\u0432\u043e \u0432\u044b\u0437\u043e\u0432\u043e\u0432=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["night", "evening", "morning", "day"], "xaxis": "x", "y": [66696, 159707, 187700, 249419], "yaxis": "y"}],                        {"barmode": "relative", "height": 500, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"out ...

# %% [markdown]
# ## Подытог: можно сказать что больше всего вызовов происходит в первой половине дня

# %% [markdown]
# # Рассмотрим топ 20 городов по вызовам 911 (Не получилось)

# %% [markdown]
# ## Не смог найти информацию по населению, чтобы посчитать количество вызовов на 1/100/1000 единиц населения

# %%
df.twp.value_counts()
# Out:
# LOWER MERION       55490
# ABINGTON           39947
# NORRISTOWN         37633
# UPPER MERION       36010
# CHELTENHAM         30574
#                    ...
# EAST GREENVILLE     1316
# BRYN ATHYN          1254
# GREEN LANE           385
# PHILA COUNTY         267
# LEHIGH COUNTY        190
# Name: twp, Length: 68, dtype: int64

# %%
city_df = pd.read_csv('data/uscities.csv')


cities = [i.lower().strip() for i in city_df.city.unique()]

df_cities = [i.lower().strip() for i in df.twp.unique() if isinstance(i, str)]

for i in df_cities:
    if 'abington' in cities:
        print('ok')

# %% [markdown]
# # Шаг 9. Попробуем посмореть распределение вызовов по широте и долготе

# %%
SAMPLE_SIZE = 10000

geo_df = df[ (df.lat > 38 ) & (df.lat < 40.5) ]
geo_df = geo_df[ (df.lng > -76) & (df.lng < -74)]

print(geo_df.shape)

geo_df = geo_df.sample(n=SAMPLE_SIZE, random_state=42)
# Out:
# <ipython-input-121-2303c369b4ff>:4: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
# (662950, 17)

# %%
import plotly.express as px
px.set_mapbox_access_token(open(".mapbox_api_key").read())


fig = px.scatter_mapbox(geo_df, lat="lat", lon="lng",
                        color_continuous_scale=px.colors.cyclical.IceFire,
                        size_max=15, zoom=8, hover_name='twp')
fig.show()
# Out:
# <div>                            <div id="58eb7c9b-c0fa-48ba-951e-95a4480ec5e1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("58eb7c9b-c0fa-48ba-951e-95a4480ec5e1")) {                    Plotly.newPlot(                        "58eb7c9b-c0fa-48ba-951e-95a4480ec5e1",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>lat=%{lat}<br>lng=%{lon}<extra></extra>", "hovertext": ["HATFIELD TOWNSHIP", "UPPER MERION", "UPPER MERION", "LOWER MERION", "PENNSBURG", "ABINGTON", "POTTSTOWN", "JENKINTOWN", "LOWER FREDERICK", "UPPER FREDERICK", "POTTSTOWN", "ABINGTON", "COLLEGEVILLE", "LIMERICK", "NORRISTOWN", "NORRISTOWN", "NEW HANOVER", "LOWER PROVIDENCE", "POTTSTOWN", "WEST NORRITON", "CONSHOHOCKEN", "UPPER MERION", "LOWER MORELAND", "ABINGTON", "CHELTENHAM", "UPPER MERION", "LOWER MERION", "SPRINGFIELD", "LIMERICK", "UPPER MERION", "LOWER MORELAND", "COLLEGEVILLE", "TELFORD", "COLLEGEVILLE", "LOWER MERION", "HORSHAM", "LOWER GWYNEDD", "LOWER MERION", "LOWER MERION", "POTTSTOWN", "LOWER MORELAND", "CHELTENHAM", "HATFIELD TOWNSHIP", "POTTSTOWN", "NORRISTOWN", "LOWER MERION", "ABINGTON", "PLYMOUTH", "UPPER MERION", "LOWER MERION", "WHITPAIN", "POTTSTOWN", "WHITEMARSH", "HATBORO", "LOWER SALFORD", "HORSHAM", "UPPER MORELAND", "NORRISTOWN", "LOWER MERION", "SOUDERTON", "WEST NORRITON", "WORCESTER", "SALFORD", "LOWER MERION", "JENKINTOWN", "NORRISTOWN", "ABINGTON", "UPPER MERION", "TOWAMENCIN", "WHITEMARSH", "UPPER MERION", "SKIPPACK", "WEST NORRITON", "UPPER MORELAND", "WHITPAIN", "LOWER PROVIDENCE", "PLYMOUTH", "ABINGTON", "POTTSTOWN", "UPPER GWYNEDD", "UPPER DUBLIN", "LOWER GWYNEDD", "WHITPAIN", "PLYMOUTH", "BRIDGEPORT", "NORRISTOWN", "MONTGOMERY", "UPPER MERION", "NORRISTOWN", "LOWER PROVIDENCE", "LOWER MERION", "MARLBOROUGH", "LOWER MERION", "UPPER PROVIDENCE", "UPPER DUBLIN", "LANSDALE", "LOWER PROVIDENCE", "WEST POTTSGROVE", "CHELTENHAM", "ROYERSFORD", "BUCKS COUNTY", "HATBORO", "UPPER PROVIDENCE", "LIMERICK", "UPPER POTTSGROVE", "NORRISTOWN", "SPRINGFIELD", "CHESTER COUNTY", "PLYMOUTH", "ABINGTON", "MONTGOMERY", "SKIPPACK", "UPPER DUBLIN", "PLYMOUTH", "DOUGLASS", "UPPER MERION", "SPRINGFIELD", "POTTSTOWN", "UPPER DUBLIN", "POTTSTOWN", "NORRISTOWN", "UPPER MORELAND", "LOWER MERION", "MONTGOMERY", "CHELTENHAM", "LOWER MERION", "CONSHOHOCKEN", "SKIPPACK", "UPPER MORELAND", "POTTSTOWN", "UPPER MERION", "CHELTENHAM", "WEST POTTSGROVE", "HATFIELD TOWNSHIP", "UPPER MERION", "UPPER MERION", "LOWER MERION", "LANSDALE", "UPPER PROVIDENCE", "COLLEGEVILLE", "AMBLER", "WHITEMARSH", "RED HILL", "WHITEMARSH", "SPRINGFIELD", "NORRISTOWN", "POTTSTOWN", "UPPER DUBLIN", "WEST POTTSGROVE", "WEST POTTSGROVE", "ROCKLEDGE", "WEST CONSHOHOCKEN", "NORRISTOWN", "WORCESTER", "SPRINGFIELD", "LOWER SALFORD", "LOWER SALFORD", "NORRISTOWN", "POTTSTOWN", "AMBLER", "PLYMOUTH", "SKIPPACK", "NORRISTOWN", "CHESTER COUNTY", "ROYERSFORD", "NORRISTOWN", "UPPER GWYNEDD", "LANSDALE", "CONSHOHOCKEN", "LOWER PROVIDENCE", "LOWER PROVIDENCE", "LOWER PROVIDENCE", "UPPER PROVIDENCE", "RED HILL", "TRAPPE", "POTTSTOWN", "LOWER MORELAND", "LOWER PROVIDENCE", "UPPER MORELAND", "SPRINGFIELD", "LIMERICK", "WEST CONSHOHOCKEN", "NORRISTOWN", "FRANCONIA", "WHITPAIN", "AMBLER", "UPPER DUBLIN", "AMBLER", "UPPER MORELAND", "MONTGOMERY", "LOWER PROVIDENCE", "WEST NORRITON", "UPPER DUBLIN", "UPPER MORELAND", "MONTGOMERY", "CHELTENHAM", "LANSDALE", "LOWER MORELAND", "PLYMOUTH", "MONTGOMERY", "PLYMOUTH", "PLYMOUTH", "UPPER MORELAND", "LOWER PROVIDENCE", "SPRINGFIELD", "NORRISTOWN", "WHITEMARSH", "LOWER MORELAND", "UPPER MERION", "NORRISTOWN", "LIMERICK", "UPPER GWYNEDD", "CHELTENHAM", "PLYMOUTH", "UPPER GWYNEDD", "WHITEMARSH", "NEW HANOVER", "UPPER MORELAND", "PLYMOUTH", "LOWER POTTSGROVE", "PLYMOUTH", "TOWAMENCIN", "AMBLER", "WHITEMARSH", "COLLE ...

# %%
import plotly.express as px
fig = px.density_mapbox(geo_df, lat='lat', lon='lng', radius=2,
                        center=dict(lat=40.17, lon=-75.27), zoom=9.5, 
                        mapbox_style="stamen-terrain", width=1000,
                        height=900, title='Карта случаев', hover_name='twp')
fig.show()
# Out:
# <div>                            <div id="27d08786-791d-4898-8ace-acd367703fb0" class="plotly-graph-div" style="height:900px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("27d08786-791d-4898-8ace-acd367703fb0")) {                    Plotly.newPlot(                        "27d08786-791d-4898-8ace-acd367703fb0",                        [{"coloraxis": "coloraxis", "hovertemplate": "<b>%{hovertext}</b><br><br>lat=%{lat}<br>lng=%{lon}<extra></extra>", "hovertext": ["HATFIELD TOWNSHIP", "UPPER MERION", "UPPER MERION", "LOWER MERION", "PENNSBURG", "ABINGTON", "POTTSTOWN", "JENKINTOWN", "LOWER FREDERICK", "UPPER FREDERICK", "POTTSTOWN", "ABINGTON", "COLLEGEVILLE", "LIMERICK", "NORRISTOWN", "NORRISTOWN", "NEW HANOVER", "LOWER PROVIDENCE", "POTTSTOWN", "WEST NORRITON", "CONSHOHOCKEN", "UPPER MERION", "LOWER MORELAND", "ABINGTON", "CHELTENHAM", "UPPER MERION", "LOWER MERION", "SPRINGFIELD", "LIMERICK", "UPPER MERION", "LOWER MORELAND", "COLLEGEVILLE", "TELFORD", "COLLEGEVILLE", "LOWER MERION", "HORSHAM", "LOWER GWYNEDD", "LOWER MERION", "LOWER MERION", "POTTSTOWN", "LOWER MORELAND", "CHELTENHAM", "HATFIELD TOWNSHIP", "POTTSTOWN", "NORRISTOWN", "LOWER MERION", "ABINGTON", "PLYMOUTH", "UPPER MERION", "LOWER MERION", "WHITPAIN", "POTTSTOWN", "WHITEMARSH", "HATBORO", "LOWER SALFORD", "HORSHAM", "UPPER MORELAND", "NORRISTOWN", "LOWER MERION", "SOUDERTON", "WEST NORRITON", "WORCESTER", "SALFORD", "LOWER MERION", "JENKINTOWN", "NORRISTOWN", "ABINGTON", "UPPER MERION", "TOWAMENCIN", "WHITEMARSH", "UPPER MERION", "SKIPPACK", "WEST NORRITON", "UPPER MORELAND", "WHITPAIN", "LOWER PROVIDENCE", "PLYMOUTH", "ABINGTON", "POTTSTOWN", "UPPER GWYNEDD", "UPPER DUBLIN", "LOWER GWYNEDD", "WHITPAIN", "PLYMOUTH", "BRIDGEPORT", "NORRISTOWN", "MONTGOMERY", "UPPER MERION", "NORRISTOWN", "LOWER PROVIDENCE", "LOWER MERION", "MARLBOROUGH", "LOWER MERION", "UPPER PROVIDENCE", "UPPER DUBLIN", "LANSDALE", "LOWER PROVIDENCE", "WEST POTTSGROVE", "CHELTENHAM", "ROYERSFORD", "BUCKS COUNTY", "HATBORO", "UPPER PROVIDENCE", "LIMERICK", "UPPER POTTSGROVE", "NORRISTOWN", "SPRINGFIELD", "CHESTER COUNTY", "PLYMOUTH", "ABINGTON", "MONTGOMERY", "SKIPPACK", "UPPER DUBLIN", "PLYMOUTH", "DOUGLASS", "UPPER MERION", "SPRINGFIELD", "POTTSTOWN", "UPPER DUBLIN", "POTTSTOWN", "NORRISTOWN", "UPPER MORELAND", "LOWER MERION", "MONTGOMERY", "CHELTENHAM", "LOWER MERION", "CONSHOHOCKEN", "SKIPPACK", "UPPER MORELAND", "POTTSTOWN", "UPPER MERION", "CHELTENHAM", "WEST POTTSGROVE", "HATFIELD TOWNSHIP", "UPPER MERION", "UPPER MERION", "LOWER MERION", "LANSDALE", "UPPER PROVIDENCE", "COLLEGEVILLE", "AMBLER", "WHITEMARSH", "RED HILL", "WHITEMARSH", "SPRINGFIELD", "NORRISTOWN", "POTTSTOWN", "UPPER DUBLIN", "WEST POTTSGROVE", "WEST POTTSGROVE", "ROCKLEDGE", "WEST CONSHOHOCKEN", "NORRISTOWN", "WORCESTER", "SPRINGFIELD", "LOWER SALFORD", "LOWER SALFORD", "NORRISTOWN", "POTTSTOWN", "AMBLER", "PLYMOUTH", "SKIPPACK", "NORRISTOWN", "CHESTER COUNTY", "ROYERSFORD", "NORRISTOWN", "UPPER GWYNEDD", "LANSDALE", "CONSHOHOCKEN", "LOWER PROVIDENCE", "LOWER PROVIDENCE", "LOWER PROVIDENCE", "UPPER PROVIDENCE", "RED HILL", "TRAPPE", "POTTSTOWN", "LOWER MORELAND", "LOWER PROVIDENCE", "UPPER MORELAND", "SPRINGFIELD", "LIMERICK", "WEST CONSHOHOCKEN", "NORRISTOWN", "FRANCONIA", "WHITPAIN", "AMBLER", "UPPER DUBLIN", "AMBLER", "UPPER MORELAND", "MONTGOMERY", "LOWER PROVIDENCE", "WEST NORRITON", "UPPER DUBLIN", "UPPER MORELAND", "MONTGOMERY", "CHELTENHAM", "LANSDALE", "LOWER MORELAND", "PLYMOUTH", "MONTGOMERY", "PLYMOUTH", "PLYMOUTH", "UPPER MORELAND", "LOWER PROVIDENCE", "SPRINGFIELD", "NORRISTOWN", "WHITEMARSH", "LOWER MORELAND", "UPPER MERION", "NORRISTOWN", "LIMERICK", "UPPER GWYNEDD", "CHELTENHAM", "PLYMOUTH", "UPPER GWYNEDD", "WHITEMARSH", "NEW HANOVER", "UPPER MORELAND", "PLYMOUTH", "LOWER POTTSGROVE", "PLYMOUTH", "TOWAMENCIN", "A ...

# %% [markdown]
# ## Подытог: рассматривалось географическое распределение вызовов некоторой случайно взятой части датасэта (семпла), наиболее часто происходили вызовы из townships(части городов?) NORRISTOWN, UPPER MORELAND, POTTSTOWN

# %% [markdown]
# # Итог
#
# ### В ходе работы был рассмотрен датасет вызовов 911 в США
#
# ### Для визуализации были использованы виды графиков: barplot, lollipop plot, line chart, area plot, doughnut (pie plot), map, density heatmap
#
# ### Были подтверждены гипотезы:
#
# * Наиболее частым является вызов в связи с увечьями, следующими по популярности являются вызовы в связи с проблемами на дороге, далее вызовы связанные с пожарами.
# * Наиболее часто обращаются в связи с проблемами с автомобилем (аварии и поломки)
# * В среднем количество вызовов за все время очень похожее
# * среднее количество вызовов 911 в день росло скачкообразно, с падением в 2017 году, вплоть до 2018 года, далее убывало до конца наблюдения - до 2020 года
# * общее количество вызовов 911 уменьшилось со временем к 2020 году
# * наиболее часто происходили вызовы из NORRISTOWN, UPPER MORELAND, POTTSTOWN
